# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

# %% [markdown]
# ### Showcase UINT8 bug

# %%
os.listdir("/dtu/3d-imaging-center/projects/2022_QIM_52_Bone/analysis/")
# Out:
# ['femur21_uint8.nii',
#  '._.DS_Store',
#  'femur01.nii',
#  'femur01_uint8.nii',
#  '.DS_Store',
#  'femur01_mod.nii',
#  'clinical_femur15.nii',
#  'femur15_uint8.nii',
#  'mct2cct_f15_reg.txt',
#  'clinical_femur74.nii',
#  'merged_tiffs',
#  'clinical_femur21.nii',
#  'femur74_uint8.nii',
#  'initialProcessing.py',
#  'clinical_femur01.nii',
#  'femur01_shift.nii']

# %%
path = "/dtu/3d-imaging-center/projects/2022_QIM_52_Bone/analysis/femur01.nii"
im = nib.load(path)
im.shape
# Out:
# (1030, 1429, 2454)

# %%
im.get_data_dtype() == np.dtype(np.uint8)
# Out:
# False

# %%
plt.imshow(im.dataobj[..., 1500], cmap="gray")
plt.show()

# %% [markdown]
# ### Read file

# %%
path = "/dtu/3d-imaging-center/projects/2022_QIM_52_Bone/analysis/femur01.nii"
im = nib.load(path)
im.shape
# Out:
# (1030, 1429, 2454)

# %%
print(f"uint8: {im.get_data_dtype() == np.dtype(np.uint8)}")
print(f"int16: {im.get_data_dtype() == np.dtype(np.int16)}")
# Out:
# uint8: False
# int16: False

# %% [markdown]
# ### Get slice

# %%
im.dataobj[..., 100].shape
# Out:
# (1030, 1429)

# %%
im.slicer[:,:,1:2].shape
# Out:
# (1030, 1429, 1)

# %%
plt.imshow(im.dataobj[..., 2300])
plt.show()
