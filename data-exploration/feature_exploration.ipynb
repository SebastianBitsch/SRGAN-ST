# %%
import torch
from skimage import io 

import matplotlib as plt
import numpy as np

# %%
loaded_image = np.load('data/features/VGG_feature_image.npy')
io.imshow(loaded_image)
# Out:
# /zhome/45/8/156251/Desktop/SRGAN-ST-1/.env/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
loaded_image = np.load('data/features/D_feature_image.npy')
io.imshow(loaded_image)
